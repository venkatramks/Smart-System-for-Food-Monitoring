# %%
import serial
import time
import joblib
import re
from flask import Flask, jsonify
from flask_cors import CORS

app = Flask(__name__)
CORS(app)

# Load model
model = joblib.load("") # replace with the path where you have your trained pkl file

# Connect to Serial
ser = serial.Serial('COM10', 115200, timeout=1)
time.sleep(2)
print("✅ Serial connected to ESP32")

# Helper: Read lines for a fixed duration
def read_lines_for(duration=1.5):
    lines = []
    start_time = time.time()
    while time.time() - start_time < duration:
        try:
            line = ser.readline().decode('utf-8', errors='ignore').strip()
            if line:
                lines.append(line)
        except Exception as e:
            print("⚠ Serial read error:", e)
    return lines

# Extract temp + hum
def extract_temp_hum(lines):
    for line in lines:
        if "Temperature:" in line and "Humidity:" in line:
            try:
                match = re.search(r'Temperature:\s*([\d.]+)°C\s*\|\s*Humidity:\s*([\d.]+)%', line)
                if match:
                    return float(match.group(1)), float(match.group(2))
            except Exception as e:
                print("❌ TEMP parse error:", e)
    return None, None

# Extract RFID (Improved & Stable)
def extract_rfid(lines):
    rfid_map = {
        "93ECB030": "FreshApple",
        "F3108AF5": "FreshBanana"
    }

    for line in lines:
        if "UID" in line or "RFID" in line or "card detected" in line:
            if "No RFID card detected" in line:
                continue  # Skip no card lines
            match = re.search(r'UID:\s*([0-9A-Fa-f\s]+)', line)
            if match:
                raw_uid = match.group(1)
                uid = raw_uid.replace(" ", "").upper()
                food_item = rfid_map.get(uid, "Unknown")
                return uid, food_item

    return None, "No Card"

# Route: Temperature only
@app.route('/temperature', methods=['GET'])
def get_temperature():
    try:
        lines = read_lines_for()
        temp, hum = extract_temp_hum(lines)
        if temp is not None and hum is not None:
            condition = model.predict([[temp, hum]])[0]
            condition_label = "✅ Safe" if condition == 0 else "⚠ Unsafe"
            return jsonify({
                "temperature": temp,
                "humidity": hum,
                "condition": condition_label
            }), 200
        return jsonify({"error": "No valid DHT data found"}), 500
    except Exception as e:
        print("❌ Error in /temperature:", e)
        return jsonify({"error": str(e)}), 500

# Route: RFID only (Stable now)
@app.route('/rfid', methods=['GET'])
def get_rfid():
    try:
        lines = read_lines_for()
        tag, status = extract_rfid(lines)
        return jsonify({
            "rfid_tag": tag,
            "rfid_status": status
        }), 200
    except Exception as e:
        print("❌ Error in /rfid:", e)
        return jsonify({"error": str(e)}), 500

# Route: Predict both
@app.route('/predict', methods=['GET'])
def predict_all():
    try:
        lines = read_lines_for(2)
        temp, hum = extract_temp_hum(lines)
        tag, status = extract_rfid(lines)

        if temp is None or hum is None:
            return jsonify({"error": "Temperature/humidity data missing"}), 500

        condition = model.predict([[temp, hum]])[0]
        condition_label = "✅ Safe" if condition == 0 else "⚠ Unsafe"

        return jsonify({
            "temperature": temp,
            "humidity": hum,
            "condition": condition_label,
            "rfid_tag": tag,
            "rfid_status": status
        }), 200
    except Exception as e:
        print("❌ Error in /predict:", e)
        return jsonify({"error": str(e)}), 500

# Run the app
app.run(host='0.0.0.0', port=5002)
# Out:
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ✅ Serial connected to ESP32
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5002
#  * Running on http://192.168.114.213:5002
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Apr/2025 21:58:55] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:58:55] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:58:58] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:58:58] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:01] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 21:59:02] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:03] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:07] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:07] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:10] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:13] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:13] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:16] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 21:59:17] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:18] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:22] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:25] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:28] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:28] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:31] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:33] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:34] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:37] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:38] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:40] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:43] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:43] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:46] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:48] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:49] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:52] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:53] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:55] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 21:59:58] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 21:59:58] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:01] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:03] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:04] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:06] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:07] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:09] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:12] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:12] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:15] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:18] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:21] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:24] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:27] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:27] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:30] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:32] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:34] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:37] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:38] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:40] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:43] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:43] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:46] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:48] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:49] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:52] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:53] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:55] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:00:58] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:00:58] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:01:54] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:01:57] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:01:58] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:00] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:02:02] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:04] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:06] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:06] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:09] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:02:12] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:13] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:15] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:16] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:18] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:21] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:21] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:24] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:02:26] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:27] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:30] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:31] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:33] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:36] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:36] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:39] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:02:41] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:42] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:45] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:46] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:48] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:51] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:51] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:54] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:02:56] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:02:58] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:01] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:02] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:04] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:07] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:07] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:10] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:12] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:13] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:16] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:19] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:22] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:24] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:26] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:27] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:30] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:31] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:33] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:36] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:36] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:39] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:41] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:42] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:45] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:46] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:48] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:51] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:51] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:54] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:03:56] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:03:57] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:00] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:01] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:03] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:06] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:06] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:09] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:11] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:13] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:16] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:19] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:22] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:25] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:27] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:28] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:31] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:32] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:34] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:36] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:36] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:40] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:41] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:04:42] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:04:48] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:19] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:21] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:23] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:26] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:27] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:29] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:32] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:32] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:35] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:38] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:38] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:41] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:42] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:44] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:47] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:47] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:50] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:52] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:53] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:56] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:05:57] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:05:59] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:02] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:02] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:05] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:07] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:08] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:11] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:12] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:14] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:17] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:20] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:22] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:26] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:26] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:28] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:06:31] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:06:31] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:15] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:07:18] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:21] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:07:24] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:31] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:07:31] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:07:33] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:35] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:07:37] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:41] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:07:42] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:45] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:47] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:07:51] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:07:53] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:07:56] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:07:58] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:01] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:03] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:06] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:08:07] "GET /temperature HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:11] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:12] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:16] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:17] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:22] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:22] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:26] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:27] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:31] "GET /rfid HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2025 22:08:32] "GET /temperature HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Apr/2025 22:08:36] "GET /rfid HTTP/1.1" 200 -
# c:\Users\venka\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [29/Apr/2025 22:08:37] "GET /temperature HTTP/1.1" 200 -
